# %% [markdown]
# ![](https://media1.giphy.com/media/Gtk0Z7J7M5Hzy/giphy.gif)

# %% [markdown]
# #Q1) Form a semi-supervised AQA task from this data, describe how you would design the experiment setup for evaluating a semi-supervised learning approach on your proposed task, provide a valid solution (e.g., model architecture) for your experiment setup

# %% [markdown]
# > ## Q1.1)Form a semi-supervised AQA task from this data,

# %% [markdown]
# > To generate a semi-supervised AQA from this data, I will make a semi-supervised AQA look like a `research approach`.
#
# > In the `research approach`, datasets used to evaluate semi-supervised learning algorithms are usually obtained simply by removing the labels of a large number of data points from the existing supervised learning dataset.
#
# > So I will remove the labels of a large number of data points from my supervised learning dataset.
#
# > So I will remove the labels from `70% to 75%` of the data points from my supervised learning dataset,and let the labels on the remaining data points

# %% [markdown]
# ---

# %% [markdown]
# > ## Q1.3)provide a valid solution (e.g., model architecture) for your experiment setup

# %% [markdown]
# > In this task, I have many architectures that I can use but I will apply `Co-Training Semi-Supervised Regression (COREG)` or `Pseudo Labeling`

# %% [markdown]
# > 1. **`Co-Training Semi-Supervised Regression (COREG): `**COREG is a non-parametric co-training style semisupervised regression algorithm, which uses two K-nearest neighbor regressors with different distance metrics to generate the scores for unlabeled videos by estimating the influence of the labeling for unlabeled videos on the labeled videos. We utilize the average of video segment features extracted by I3D as the input of COREG.
#
# > 2. **`Pseudo Labeling: `** I will apply the Pseudo-labeling method with the semi-supervised regression to train our dataset after converting it to a semi-supervised task, by using the k nearest neighbor algorithm to generate the pseudo labels for unlabeled videos by the distance metric between labeled videos and unlabeled videos in the embedding space, then make predictions on a subset of unlabeled data, then Pick confident predictions, and add them to training data, and repeat it until labeling all the unlabeled data

# %% [markdown]
# > `AQA dataset:` With 1412 samples,it is the largest AQA
# dataset to date. This particular dataset focuses only on Diving as it has seen the most usage recently. Data has `[events, Height, Genders, View Variation /Background, Labels]` as features

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > `The input features: ` it will be the video segment features
# extracted by the I3D over the labeled training samples

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > `The output:` the prediction of the action scores

# %% [markdown]
# ---

# %% [markdown]
# > ## Q1.2)describe how you would design the experiment setup for evaluating a semi-supervised learning approach on your proposed task,

# %% [markdown]
# > To evaluate our approach, I will compare the prediction results for the methods (prediction labels) with the original labels for the dataset
#
# > To compare the original labels with the prediction labels, I'll use the mean squared error (MSE) loss, which is written as

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# > where
# * `y ` is original labels (true values)
# * `y'` is the prediction labels,
# * `N ` is the total number of labeled training samples.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Q2)Read the paper titled “What and How Well You Performed? A Multitask Learning Approach to Action Quality Assessment”, summarize their paper by answering
# 1. how they form a multi-task learning task from the given dataset?
# 2. besides their proposed multi-task learning problem, do you think other multi-task problems can be formed from the AQA context? Give at least one example.
# 3. provide another application that can benefit from their multi-task learning approach.

# %% [markdown]
# > ## Q2.1)how they form a multi-task learning task from the given dataset?

# %% [markdown]
# > in the beginning we need to know what's the meaning of  `multi-task learning (MTL)`
#
# > `MTL: `is a machine learning paradigm in which a single model caters to more than a single task. An example is to recognize road signs, roads, and vehicles together, MTL tasks are generally chosen such that they are related to one another and their networks have a common body that branches into task specific heads. The total network loss is the sum of individual task losses.

# %% [markdown]
# >> ### `MTL-AQA (Origin of two auxiliary tasks)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>`**Form a MTL Task**`
#
# > From the MTL definition: There is a single model that caters to more than a single task and we have three tasks in this problem that are in the same model
# * Action Quality Score:
# * AQA-oriented Caption Generation
# * Factorized Action Recognition
#
#
# > In the following image, I will show the three tasks that make this task a `multi-task learning (MTL)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---

# %% [markdown]
# >> ### Multitask Approach to AQA

# %% [markdown]
# > 1)<font color='red'>**`Task selection: `**</font> our main task is the prediction of action quality score, In order to characterize the procedure, we consider the familiarization with the detailed procedure an auxiliary task, which will be responsible for the procedure part. Creating a verbal comment describing the good and bad points of the performance becomes a helpful task that deals with how good the part is

# %% [markdown]
# > 2)<font color='red'>**`Formalization: `**</font> We will formalize the problem settings and objective functions.
#
# * `AQA: ` is a regression problem, therefore, AQA branch produces sum of Euclidean loss and L1 loss. We found that using L1 loss in addition to L2 loss yields better results.
#
# * `detailed action recognition: ` that means detailed dive recognition in particular. A dive can be broken down into five components. Detailed dive identification refers to identifying each one of these five components. The detailed dive classification branch produces five cross-entropy losses.
#
# * `Commentary generation: ` is a captioning task. So, commentary generation branch produces negative log-likelihood loss.
#
# * The overall loss is a sum of three losses described above

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > As discussed previously, `MTL architectures` have a common body and task-specific heads, So we will use `3D CNN’s` to compute `spatiotemporal features` for `small clips`, and then `aggregate` those to get `whole video-level features`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >this is the three prediction tasks
# 1. Action Quality Score
# 2. AQA-oriented Caption Generation
# 3. Factorized Action Recognition

# %% [markdown]
# ---

# %% [markdown]
# > ## Q2.2)besides their proposed multi-task learning problem, do you think other multi-task problems can be formed from the AQA context? Give at least one example.

# %% [markdown]
# > Yes there are, Such as
# 1. text to speech generation:  for score and the Caption Generation
#   * `(voice commentary)`
# 2. detect the time of jumping, landing minute, number of Rotation and the speed of diving
#   * `(Action regoginition)`
# 3. detect the height and the gender of the diver
# 4. provide a feedback like a coach for a diver.

# %% [markdown]
# ---

# %% [markdown]
# > ## Q2.3)provide another application that can benefit from their multi-task learning approach.

# %% [markdown]
# > * #### **Physical rehabilitation and workout programs**
#     * During physical rehabilitation, patients are required to perform exercises that enable them to regain mobility or conditioning. Physical therapists monitor and evaluate how patients perform these recommended exercises. Low-cost home automated physical rehabilitation options can be made available using automated assessment of exercises (which are essentially procedures) using computer vision. `to evaluate if the patient is doing exercises correctly or not.`

# %% [markdown]
# <img src="https://developers.google.com/ml-kit/images/vision/pose-detection/pose_classification.gif" width="400"/> | <img src="https://developers.google.com/ml-kit/images/vision/pose-detection/jump.gif" width="400"/>

# %% [markdown]
# ---

# %% [markdown]
# > * #### **Automated Olympics judging**
#     * Bias and scandals involving unequal judgments are nothing new in sports arbitration. `A computer vision system can be used to judge sports` to provide a second opinion in the event of a controversial decision being made. This type of system can also be `used to detect whether a judgment is unequal or not`. An automated work quality assessment system can be `used to serve as a judge of performances` (`diving, gymnastics, skiing, acrobatic gymnastics, archery,etc.`), as well as `provide feedback like a coach.`
#
# >
#   * This application also calculates the score and provides feedback about the movements and stability and other features depending on the type of the game

# %% [markdown]
# > <img src="https://c.tenor.com/ee0ixuRjfR4AAAAM/archery-bullseye.gif" width="350"/> | <img src="https://i.gifer.com/6Od.gif" width="350"/> | <img src="https://64.media.tumblr.com/f3294604cbc6dfc5bb869a4c3642ed36/tumblr_oawj6caqMP1u25kiio1_1280.gifv" width="350"/>

# %% [markdown]
# ---

# %% [markdown]
# > * #### **Assessing skills:**
#     * There’s always a demand for skilled labor. But honing those skills requires hours and hours of practice and feedback. Automated vision-based skills assessment systems can be very handy in these situations. Such a system can be `used to monitor the performance and progress of a person practicing to develop the skills`, and also `provide feedback in case of erroneous execution.` These systems can be useful in `assessing skills of everyday activities (drawing, painting, applying make-up, etc.)`, and `specialized activities (surgical skills, pottery, woodworking, spray painting, etc.).`

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# > # Resources
# [Ref.](https://slideplayer.com/slide/17502578/)
# [Ref.](https://digitalscholarship.unlv.edu/cgi/viewcontent.cgi?article=4837&context=thesesdissertations)
# [Ref.](https://github.com/ParitoshParmar/MTL-AQA)
